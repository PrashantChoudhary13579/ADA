# %%
import matplotlib.pyplot as plt

# %%
x1 = [10 , 100 , 1000 , 10000 , 100000 , 1000000 , 10000000 , 100000000 ]
y = [0,0,0,0,6884000,58610000,596760000,6189524000]

plt.plot(x1,y)
plt.ticklabel_format(useOffset=False,style ="plain")
plt.show()
